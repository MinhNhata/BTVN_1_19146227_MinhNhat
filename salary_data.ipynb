# %% [markdown]
# <a href="https://colab.research.google.com/github/MinhNhata/BTVN_1_19146227_MinhNhat/blob/main/salary_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model 

url = '/content/Salary_Data.csv'
data = pd.read_csv(url)
data.hist()  
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
correlation = data.corr()
print(correlation)
sns.heatmap(correlation, annot = True)
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000
# <Axes: >

# %%
sns.pairplot(data)

# %%
data.plot(kind='scatter', x='Salary', y='YearsExperience', figsize=(9,9), color='black')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Salary', ylabel='YearsExperience'>

# %%
#BAC1
model = linear_model.LinearRegression()
X=pd.DataFrame(data['Salary'])
y=data['YearsExperience']
model.fit(X, y)
print('Intercept cua mo hinh  : ', model.intercept_)
print('Coefient cua mo hinh : ', model.coef_)
print('Do chinh xac cua mo hinh : ', model.score(X,y))

range = np.arange(data['Salary'].min(), data['Salary'].max(),0.1)
data.plot(kind='scatter', x='Salary', y='YearsExperience', figsize=(9,9), color='black', xlim=0.7)
predictor = pd.DataFrame(range)
y_pred = model.predict(X=predictor)
plt.plot(range, y_pred, color='red')
# Out:
# Intercept cua mo hinh  :  -2.3831605648243537
# Coefient cua mo hinh :  [0.00010127]
# Do chinh xac cua mo hinh :  0.9569566641435086
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#BAC3
model = linear_model.LinearRegression()
X=pd.DataFrame([data['Salary'], data['Salary']**2, data['Salary']**3]).T
y=data['YearsExperience']
model.fit(X, y)
print('Intercept cua mo hinh : ', model.intercept_)
print('Coefient cua mo hinh : ', model.coef_)
print('Do chinh xac cua mo hinh : ', model.score(X,y))

range = np.arange(data['Salary'].min(), data['Salary'].max(), 0.1)
data.plot(kind='scatter', x='Salary', y='YearsExperience', figsize=(9,9), color='black', xlim=0.7)
predictor = pd.DataFrame([range, range**2, range**3]).T
y_pred = model.predict(X=predictor)
plt.plot(range, y_pred, color='red')
# Out:
# Intercept cua mo hinh :  -6.193134376067245
# Coefient cua mo hinh :  [ 2.78222615e-04 -2.53776109e-09  1.12287280e-14]
# Do chinh xac cua mo hinh :  0.9607554847155427
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#BAC 6
model = linear_model.LinearRegression()
X=pd.DataFrame([data['Salary'], data['Salary']**2, data['Salary']**3, data['Salary']**4, data['Salary']**5, data['Salary']**6]).T
y=data['YearsExperience']
model.fit(X, y)
print('Intercept của mô hình : ', model.intercept_)
print('Coefient của mô hình : ', model.coef_)
print('Độ chính xác của mô hình : ', model.score(X,y))

range = np.arange(data['Salary'].min(), data['Salary'].max(), 0.1)
data.plot(kind='scatter', x='Salary', y='YearsExperience', figsize=(9,9), color='black', xlim=0.7)
predictor = pd.DataFrame([range, range**2, range**3, range**4, range**5, range**6]).T
y_pred = model.predict(X=predictor)
plt.plot(range, y_pred, color='red')
# Out:
# Intercept của mô hình :  1.1519713212623879
# Coefient của mô hình :  [ 3.20520214e-33 -1.00538395e-23  1.63535258e-23  5.82668586e-19
#  -8.60874841e-24  3.42495148e-29]
# Độ chính xác của mô hình :  0.9534915811013813
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
